# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_excel("D:\\College Study work\\Sem 6\\DSBDAL\\Student_Performance.xlsx")
df.isnull()
# Out:
#     math_score  reading_score  writing_score  placement_score  club_join_year  \
# 0        False          False          False            False           False
# 1        False          False          False            False           False
# 2        False          False          False            False           False
# 3        False          False          False            False           False
# 4        False          False          False            False           False
# 5         True          False          False            False           False
# 6        False          False          False            False           False
# 7        False          False           True            False           False
# 8        False          False          False            False           False
# 9        False          False          False            False           False
# 10       False          False          False            False           False
# ...

# %%
series = pd.isnull(df["math_score"])
df[series]
# Out:
#     math_score  reading_score  writing_score placement_score  club_join_year  \
# 5          NaN           75.0           62.0              78            2019
# 15         NaN           63.0           67.0              na            2018
# 27         NaN           79.0           73.0              80            2019
#
#     Placement-offer-count
# 5                       0
# 15                      0
# 27                      0

# %%
df.notnull()
# Out:
#     math_score  reading_score  writing_score  placement_score  club_join_year  \
# 0         True           True           True             True            True
# 1         True           True           True             True            True
# 2         True           True           True             True            True
# 3         True           True           True             True            True
# 4         True           True           True             True            True
# 5        False           True           True             True            True
# 6         True           True           True             True            True
# 7         True           True          False             True            True
# 8         True           True           True             True            True
# 9         True           True           True             True            True
# 10        True           True           True             True            True
# ...

# %%
series1 = pd.notnull(df["writing_score"])
df[series1]
# Out:
#     math_score  reading_score  writing_score placement_score  club_join_year  \
# 0         77.0           73.0           69.0              65            2020
# 1         75.0           70.0           58.0              94            2018
# 2         75.0           63.0           61.0              69            2019
# 3         69.0           70.0           71.0              73            2019
# 4         97.0           50.0           64.0              77            2018
# 5          NaN           75.0           62.0              78            2019
# 6         77.0           71.0           74.0              66            2019
# 8         70.0           67.0           69.0              62            2019
# 9         55.0           20.0           74.0              75            2021
# 10        73.0           77.0           77.0              60            2018
# 11        64.0           60.0           73.0              75            2021
# ...

# %%
missing_values = ["Na","na"]
df1 = pd.read_excel("D:\\College Study work\\Sem 6\\DSBDAL\\Student_Performance.xlsx", na_values = missing_values)
df1
# Out:
#     math_score  reading_score  writing_score  placement_score  club_join_year  \
# 0         77.0           73.0           69.0             65.0            2020
# 1         75.0           70.0           58.0             94.0            2018
# 2         75.0           63.0           61.0             69.0            2019
# 3         69.0           70.0           71.0             73.0            2019
# 4         97.0           50.0           64.0             77.0            2018
# 5          NaN           75.0           62.0             78.0            2019
# 6         77.0           71.0           74.0             66.0            2019
# 7         66.0           70.0            NaN             77.0            2019
# 8         70.0           67.0           69.0             62.0            2019
# 9         55.0           20.0           74.0             75.0            2021
# 10        73.0           77.0           77.0             60.0            2018
# ...

# %%
ndf=df
ndf.fillna(0)
# Out:
#     math_score  reading_score  writing_score placement_score  club_join_year  \
# 0         77.0           73.0           69.0              65            2020
# 1         75.0           70.0           58.0              94            2018
# 2         75.0           63.0           61.0              69            2019
# 3         69.0           70.0           71.0              73            2019
# 4         97.0           50.0           64.0              77            2018
# 5          0.0           75.0           62.0              78            2019
# 6         77.0           71.0           74.0              66            2019
# 7         66.0           70.0            0.0              77            2019
# 8         70.0           67.0           69.0              62            2019
# 9         55.0           20.0           74.0              75            2021
# 10        73.0           77.0           77.0              60            2018
# ...

# %%
df['math_score'] = df['math_score'].fillna(df['math_score'].mean())
df
# Out:
#     math_score  reading_score  writing_score placement_score  club_join_year  \
# 0    77.000000           73.0           69.0              65            2020
# 1    75.000000           70.0           58.0              94            2018
# 2    75.000000           63.0           61.0              69            2019
# 3    69.000000           70.0           71.0              73            2019
# 4    97.000000           50.0           64.0              77            2018
# 5    71.222222           75.0           62.0              78            2019
# 6    77.000000           71.0           74.0              66            2019
# 7    66.000000           70.0            NaN              77            2019
# 8    70.000000           67.0           69.0              62            2019
# 9    55.000000           20.0           74.0              75            2021
# 10   73.000000           77.0           77.0              60            2018
# ...

# %%
df1['math_score'] = df1['math_score'].fillna(df1['math_score'].median())
df1
# Out:
#     math_score  reading_score  writing_score  placement_score  club_join_year  \
# 0         77.0           73.0           69.0             65.0            2020
# 1         75.0           70.0           58.0             94.0            2018
# 2         75.0           63.0           61.0             69.0            2019
# 3         69.0           70.0           71.0             73.0            2019
# 4         97.0           50.0           64.0             77.0            2018
# 5         70.0           75.0           62.0             78.0            2019
# 6         77.0           71.0           74.0             66.0            2019
# 7         66.0           70.0            NaN             77.0            2019
# 8         70.0           67.0           69.0             62.0            2019
# 9         55.0           20.0           74.0             75.0            2021
# 10        73.0           77.0           77.0             60.0            2018
# ...

# %%
df2 = pd.read_excel("D:\\College Study work\\Sem 6\\DSBDAL\\Student_Performance.xlsx")

df2['math_score'] = df2['math_score'].fillna(df2['math_score'].median())
df2
# Out:
#     math_score  reading_score  writing_score placement_score  club_join_year  \
# 0         77.0           73.0           69.0              65            2020
# 1         75.0           70.0           58.0              94            2018
# 2         75.0           63.0           61.0              69            2019
# 3         69.0           70.0           71.0              73            2019
# 4         97.0           50.0           64.0              77            2018
# 5         70.0           75.0           62.0              78            2019
# 6         77.0           71.0           74.0              66            2019
# 7         66.0           70.0            NaN              77            2019
# 8         70.0           67.0           69.0              62            2019
# 9         55.0           20.0           74.0              75            2021
# 10        73.0           77.0           77.0              60            2018
# ...

# %%
df1['reading_score'] = df1['reading_score'].fillna(df1['reading_score'].max())
df1
# Out:
#     math_score  reading_score  writing_score  placement_score  club_join_year  \
# 0         77.0           73.0           69.0             65.0            2020
# 1         75.0           70.0           58.0             94.0            2018
# 2         75.0           63.0           61.0             69.0            2019
# 3         69.0           70.0           71.0             73.0            2019
# 4         97.0           50.0           64.0             77.0            2018
# 5         70.0           75.0           62.0             78.0            2019
# 6         77.0           71.0           74.0             66.0            2019
# 7         66.0           70.0            NaN             77.0            2019
# 8         70.0           67.0           69.0             62.0            2019
# 9         55.0           20.0           74.0             75.0            2021
# 10        73.0           77.0           77.0             60.0            2018
# ...

# %%
df['reading_score'] = df['reading_score'].fillna(df['reading_score'].max())
df
# Out:
#     math_score  reading_score  writing_score placement_score  club_join_year  \
# 0    77.000000           73.0           69.0              65            2020
# 1    75.000000           70.0           58.0              94            2018
# 2    75.000000           63.0           61.0              69            2019
# 3    69.000000           70.0           71.0              73            2019
# 4    97.000000           50.0           64.0              77            2018
# 5    71.222222           75.0           62.0              78            2019
# 6    77.000000           71.0           74.0              66            2019
# 7    66.000000           70.0            NaN              77            2019
# 8    70.000000           67.0           69.0              62            2019
# 9    55.000000           20.0           74.0              75            2021
# 10   73.000000           77.0           77.0              60            2018
# ...

# %%
m_v = df['writing_score'].mean()
df['writing_score'].fillna(value=m_v, inplace=True)
df
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_8488\484603080.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['writing_score'].fillna(value=m_v, inplace=True)
#     math_score  reading_score  writing_score placement_score  club_join_year  \
# 0    77.000000           73.0      69.000000              65            2020
# 1    75.000000           70.0      58.000000              94            2018
# 2    75.000000           63.0      61.000000              69            2019
# ...

# %%
df3= pd.read_excel("D:\\College Study work\\Sem 6\\DSBDAL\\Student_Performance.xlsx")

df3.replace(to_replace = np.nan, value = -99)
# Out:
#     math_score  reading_score  writing_score placement_score  club_join_year  \
# 0         77.0           73.0           69.0              65            2020
# 1         75.0           70.0           58.0              94            2018
# 2         75.0           63.0           61.0              69            2019
# 3         69.0           70.0           71.0              73            2019
# 4         97.0           50.0           64.0              77            2018
# 5        -99.0           75.0           62.0              78            2019
# 6         77.0           71.0           74.0              66            2019
# 7         66.0           70.0          -99.0              77            2019
# 8         70.0           67.0           69.0              62            2019
# 9         55.0           20.0           74.0              75            2021
# 10        73.0           77.0           77.0              60            2018
# ...

# %%
ndf= pd.read_excel("D:\\College Study work\\Sem 6\\DSBDAL\\Student_Performance.xlsx")

ndf.dropna()
# Out:
#     math_score  reading_score  writing_score placement_score  club_join_year  \
# 0         77.0           73.0           69.0              65            2020
# 1         75.0           70.0           58.0              94            2018
# 2         75.0           63.0           61.0              69            2019
# 3         69.0           70.0           71.0              73            2019
# 4         97.0           50.0           64.0              77            2018
# 6         77.0           71.0           74.0              66            2019
# 8         70.0           67.0           69.0              62            2019
# 9         55.0           20.0           74.0              75            2021
# 10        73.0           77.0           77.0              60            2018
# 11        64.0           60.0           73.0              75            2021
# 12        73.0           60.0           73.0              95            2021
# ...

# %%
ndf.dropna(how ='all')
# Out:
#     math_score  reading_score  writing_score placement_score  club_join_year  \
# 0         77.0           73.0           69.0              65            2020
# 1         75.0           70.0           58.0              94            2018
# 2         75.0           63.0           61.0              69            2019
# 3         69.0           70.0           71.0              73            2019
# 4         97.0           50.0           64.0              77            2018
# 5          NaN           75.0           62.0              78            2019
# 6         77.0           71.0           74.0              66            2019
# 7         66.0           70.0            NaN              77            2019
# 8         70.0           67.0           69.0              62            2019
# 9         55.0           20.0           74.0              75            2021
# 10        73.0           77.0           77.0              60            2018
# ...

# %%
ndf.dropna(axis = 1)
# Out:
#     club_join_year  Placement-offer-count
# 0             2020                      2
# 1             2018                      0
# 2             2019                      2
# 3             2019                      2
# 4             2018                      0
# 5             2019                      0
# 6             2019                      2
# 7             2019                      0
# 8             2019                      2
# 9             2021                      0
# 10            2018                      2
# 11            2021                      0
# 12            2021                      0
# 13            2019                      0
# 14            2021                      2
# 15            2018                      0
# 16            2019                      0
# 17            2018                      0
# 18            2019                      2
# 19            2020                      0
# 20            2021                      0
# ...

# %%
new_data = ndf.dropna(axis = 0, how ='any')
new_data
# Out:
#     math_score  reading_score  writing_score placement_score  club_join_year  \
# 0         77.0           73.0           69.0              65            2020
# 1         75.0           70.0           58.0              94            2018
# 2         75.0           63.0           61.0              69            2019
# 3         69.0           70.0           71.0              73            2019
# 4         97.0           50.0           64.0              77            2018
# 6         77.0           71.0           74.0              66            2019
# 8         70.0           67.0           69.0              62            2019
# 9         55.0           20.0           74.0              75            2021
# 10        73.0           77.0           77.0              60            2018
# 11        64.0           60.0           73.0              75            2021
# 12        73.0           60.0           73.0              95            2021
# ...

# %%
import seaborn as sns
col = ['math_score', 'reading_score' , 'writing_score']
df.boxplot(col)
# Out:
# <Axes: >

# %%
print(np.where(df['math_score']>90))
print(np.where(df['reading_score']<25))
print(np.where(df['writing_score']<30))
# Out:
# (array([ 4, 26], dtype=int64),)
# (array([9], dtype=int64),)
# (array([26], dtype=int64),)

# %%
df4= pd.read_excel("D:\\College Study work\\Sem 6\\DSBDAL\\Student_Performance1.xlsx")

fig, ax = plt.subplots(figsize = (18,10))
ax.scatter(df4['placement_score'], df4['Placement-offer-count'])
plt.show()
ax.set_xlabel('Placement_score')
ax.set_ylabel('placement-offer-count')
# Out:
# Text(4.444444444444452, 0.5, 'placement-offer-count')

# %%
from scipy import stats
z = np.abs(stats.zscore(df['math_score']))
print(z)
# Out:
# [6.29824338e-01 4.11808221e-01 4.11808221e-01 2.42240130e-01
#  2.80998551e+00 1.54909768e-15 6.29824338e-01 5.69264305e-01
#  1.33232071e-01 1.76835295e+00 1.93792104e-01 7.87280422e-01
#  1.93792104e-01 8.47840454e-02 3.02800162e-01 1.54909768e-15
#  6.78272363e-01 1.71990492e+00 2.42240130e-02 4.60256247e-01
#  1.00529654e+00 4.60256247e-01 5.69264305e-01 8.96288480e-01
#  4.60256247e-01 1.76835295e+00 2.70097745e+00 1.54909768e-15
#  1.33232071e-01 1.33232071e-01]

# %%
threshold = 0.18 
sample_outliers = np.where(z < threshold)
sample_outliers
# Out:
# (array([ 5,  8, 13, 15, 18, 27, 28, 29], dtype=int64),)

# %%
sorted_rscore= sorted(df['reading_score'])
sorted_rscore
# Out:
# [20.0,
#  50.0,
#  60.0,
#  60.0,
#  60.0,
#  61.0,
#  62.0,
#  63.0,
#  63.0,
#  67.0,
#  68.0,
#  69.0,
#  69.0,
#  69.0,
#  70.0,
#  70.0,
#  70.0,
#  71.0,
#  71.0,
#  73.0,
#  74.0,
#  74.0,
#  75.0,
#  76.0,
#  77.0,
#  77.0,
#  79.0,
#  79.0,
#  86.0,
#  86.0]

# %%
q1 = np.percentile(sorted_rscore, 25)
q3 = np.percentile(sorted_rscore, 75)
print(q1,q3)
# Out:
# 63.0 74.75

# %%
IQR = q3-q1

# %%
lwr_bound = q1-(1.5*IQR)
upr_bound = q3+(1.5*IQR)
print(lwr_bound, upr_bound)
# Out:
# 45.375 92.375

# %%
r_outliers = []
for i in sorted_rscore:
    if (i<lwr_bound or i>upr_bound):
        r_outliers.append(i)
print(r_outliers)
# Out:
# [20.0]

# %%
new_df=df
for i in sample_outliers:
    new_df.drop(i,inplace=True)
new_df
# Out:
#     math_score  reading_score  writing_score placement_score  club_join_year  \
# 0         77.0           73.0      69.000000              65            2020
# 1         75.0           70.0      58.000000              94            2018
# 2         75.0           63.0      61.000000              69            2019
# 3         69.0           70.0      71.000000              73            2019
# 4         97.0           50.0      64.000000              77            2018
# 6         77.0           71.0      74.000000              66            2019
# 7         66.0           70.0      67.413793              77            2019
# 9         55.0           20.0      74.000000              75            2021
# 10        73.0           77.0      77.000000              60            2018
# 11        64.0           60.0      73.000000              75            2021
# 12        73.0           60.0      73.000000              95            2021
# ...

# %%
df_stud=df
ninetieth_percentile = np.percentile(df_stud['math_score'], 90)
b = np.where(df_stud['math_score']>ninetieth_percentile,
ninetieth_percentile, df_stud['math_score'])
print("New array:",b)
# Out:
# New array: [77. 75. 75. 69. 86. 77. 66. 55. 73. 64. 73. 74. 65. 86. 67. 62. 67. 66.
#  63. 67. 55. 86.]

# %%
df_stud.insert(1,"m score",b,True)
df_stud
# Out:
#     math_score  m score  reading_score  writing_score placement_score  \
# 0         77.0     77.0           73.0      69.000000              65
# 1         75.0     75.0           70.0      58.000000              94
# 2         75.0     75.0           63.0      61.000000              69
# 3         69.0     69.0           70.0      71.000000              73
# 4         97.0     86.0           50.0      64.000000              77
# 6         77.0     77.0           71.0      74.000000              66
# 7         66.0     66.0           70.0      67.413793              77
# 9         55.0     55.0           20.0      74.000000              75
# 10        73.0     73.0           77.0      77.000000              60
# 11        64.0     64.0           60.0      73.000000              75
# 12        73.0     73.0           60.0      73.000000              95
# 14        74.0     74.0           69.0      68.000000              70
# ...

# %%
col1 = ['reading_score']
df.boxplot(col1)
plt.show()

# %%
median=np.median(sorted_rscore)
median
# Out:
# 70.0

# %%
refined_df=df
refined_df['reading score'] = np.where(refined_df['reading_score'] >upr_bound, median,refined_df['reading_score'])
refined_df
# Out:
#     math_score  m score  reading_score  writing_score placement_score  \
# 0         77.0     77.0           73.0      69.000000              65
# 1         75.0     75.0           70.0      58.000000              94
# 2         75.0     75.0           63.0      61.000000              69
# 3         69.0     69.0           70.0      71.000000              73
# 4         97.0     86.0           50.0      64.000000              77
# 6         77.0     77.0           71.0      74.000000              66
# 7         66.0     66.0           70.0      67.413793              77
# 9         55.0     55.0           20.0      74.000000              75
# 10        73.0     73.0           77.0      77.000000              60
# 11        64.0     64.0           60.0      73.000000              75
# 12        73.0     73.0           60.0      73.000000              95
# 14        74.0     74.0           69.0      68.000000              70
# ...

# %%
refined_df['reading_score'] = np.where(refined_df['reading_score'] <lwr_bound, median,refined_df['reading_score'])
refined_df
# Out:
#     math_score  m score  reading_score  writing_score placement_score  \
# 0         77.0     77.0           73.0      69.000000              65
# 1         75.0     75.0           70.0      58.000000              94
# 2         75.0     75.0           63.0      61.000000              69
# 3         69.0     69.0           70.0      71.000000              73
# 4         97.0     86.0           50.0      64.000000              77
# 6         77.0     77.0           71.0      74.000000              66
# 7         66.0     66.0           70.0      67.413793              77
# 9         55.0     55.0           70.0      74.000000              75
# 10        73.0     73.0           77.0      77.000000              60
# 11        64.0     64.0           60.0      73.000000              75
# 12        73.0     73.0           60.0      73.000000              95
# 14        74.0     74.0           69.0      68.000000              70
# ...

# %%
col = ['reading_score']
refined_df.boxplot(col)
plt.show()

# %%
new_df['math_score'].plot(kind = 'hist')
plt.show()
df['log_math'] = np.log10(df['math_score'])
df['log_math'].plot(kind = 'hist')
plt.show()
